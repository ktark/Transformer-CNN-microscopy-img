# %%
import numpy as np
import matplotlib.pyplot as plt

npz_data = np.load("data\\Synapse\\train_npz\\case0007_slice111.npz")
print(npz_data.files)
image = npz_data['image']
label = npz_data['label']
print(image.shape, label.shape)

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('image and label')
ax1.imshow(image)
ax2.imshow(label)
# Out:
# ['image', 'label']
# (512, 512) (512, 512)

# %%
import h5py
hf = h5py.File('data\\Synapse\\test_vol_h5\\case0001.npy.h5', 'r')

# %%
list(hf.keys())
test_images = hf['image']
test_labels = hf['label']

# %%
test_images[0].shape
# Out:
# (512, 512)

# %%
index = 100
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('image and label')
ax1.imshow(test_images[index])
ax2.imshow(test_labels[index])

# %%
uni_test_data_bri = np.load("University data\\Dataset\\Brightfield\\X_1080_test_AIS_CONTRAST2_thesis.npy")
uni_test_data_flo = np.load("University data\\Dataset\\Fluorescent\\X_1080_test_FL_thesis.npy")
uni_test_label = np.load("University data\\Dataset\\Ground_Truth\\SCL_Y_test_504x1080x1080x1_W_DISCARDED.npy")

# %%
idx = 20
print(uni_test_data_bri[idx].shape,uni_test_data_flo[idx].shape, uni_test_label[idx].shape)
image_bri = uni_test_data_bri[idx]
image_flo = uni_test_data_flo[idx]
label = uni_test_label[idx]

fig, (ax1, ax3, ax2) = plt.subplots(1, 3, figsize=(15,15))
ax1.imshow(image_bri, cmap='gist_yarg')
ax2.imshow(image_flo)
ax3.imshow(label)
plt.show()
# Out:
# (1080, 1080, 1) (1080, 1080, 1) (1080, 1080, 1)

# %%
test_images.shape
# Out:
# (147, 512, 512)

# %%
# !pip install nibabel
# Out:
# Collecting nibabel
#   Downloading nibabel-3.2.1-py3-none-any.whl (3.3 MB)
# Requirement already satisfied: packaging>=14.3 in c:\anaconda3\lib\site-packages (from nibabel) (20.4)
# Requirement already satisfied: numpy>=1.14 in c:\anaconda3\lib\site-packages (from nibabel) (1.19.2)
# Requirement already satisfied: six in c:\anaconda3\lib\site-packages (from packaging>=14.3->nibabel) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\anaconda3\lib\site-packages (from packaging>=14.3->nibabel) (2.4.7)
# Installing collected packages: nibabel
# Successfully installed nibabel-3.2.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from nibabel.testing import data_path

example_filename =  'tmp\\case0038_pred.nii.gz'

import nibabel as nib
img = nib.load(example_filename)

# %%
img.dataobj[:,:,0].shape
# Out:
# (512, 512)

# %%
fig, (ax1, ax3, ax2) = plt.subplots(1, 3, figsize=(15,15))
ax1.imshow(img.dataobj[:,:,1])
ax2.imshow(img.dataobj[:,:,2])
ax3.imshow(img.dataobj[:,:,3])
plt.show()

# %%
uni_test_data_bri = np.load("University data\\Dataset\\Brightfield\\X_1080_test_AIS_CONTRAST2_thesis.npy")
#uni_test_data_flo = np.load("University data\\Dataset\\Fluorescent\\X_1080_test_FL_thesis.npy")
uni_test_label = np.load("University data\\Dataset\\Ground_Truth\\SCL_Y_test_504x1080x1080x1_W_DISCARDED.npy")

# %%
uni_test_label[0].shape
# Out:
# (1080, 1080, 1)

# %%
for i in np.arange(0,uni_test_data_bri.shape[0]):
    single_bri = uni_test_data_bri[0].reshape(1080,1080)
    single_label = uni_test_label[0].reshape(1080,1080)
    np.savez_compressed('University data\\prepared\\test\\image_'+str(i)+'.npz', image=single_bri, label=single_label)

# %%
uni_train_data_bri = np.load("University data\\Dataset\\Brightfield\\X_1080_train_AIS_CONTRAST2_thesis.npy")
#uni_test_data_flo = np.load("University data\\Dataset\\Fluorescent\\X_1080_test_FL_thesis.npy")
uni_train_label = np.load("University data\\Dataset\\Ground_Truth\\SCL_Y_train_2016x1080x1080x1_W_DISCARDED.npy")

for i in np.arange(0,uni_train_data_bri.shape[0]):
    single_bri = uni_train_data_bri[0].reshape(1080,1080)
    single_label = uni_train_label[0].reshape(1080,1080)
    np.savez_compressed('University data\\prepared\\train\\image_'+str(i)+'.npz', image=single_bri, label=single_label)

# %%
uni_val_data_bri = np.load("University data\\Dataset\\Brightfield\\X_1080_val_AIS_CONTRAST2_thesis.npy")
#uni_test_data_flo = np.load("University data\\Dataset\\Fluorescent\\X_1080_test_FL_thesis.npy")
uni_val_label = np.load("University data\\Dataset\\Ground_Truth\\SCL_Y_val_504x1080x1080x1_W_DISCARDED.npy")

for i in np.arange(0,uni_val_data_bri.shape[0]):
    single_bri = uni_val_data_bri[0].reshape(1080,1080)
    single_label = uni_val_label[0].reshape(1080,1080)
    np.savez_compressed('University data\\prepared\\train\\image_val_'+str(i)+'.npz', image=single_bri, label=single_label)

# %%
import os
import sys    

file_path = 'University data\\prepared\\train_images.txt'
img_path =  'University data\\prepared\\train\\'
with open(file_path,'w') as f:
        f.writelines(['{}\n'.format(os.path.splitext(line)[0]) for line in os.listdir(img_path)])

# %%
os.listdir(img_path)
# Out:
# ['image_0.npz',
#  'image_1.npz',
#  'image_10.npz',
#  'image_100.npz',
#  'image_1000.npz',
#  'image_1001.npz',
#  'image_1002.npz',
#  'image_1003.npz',
#  'image_1004.npz',
#  'image_1005.npz',
#  'image_1006.npz',
#  'image_1007.npz',
#  'image_1008.npz',
#  'image_1009.npz',
#  'image_101.npz',
#  'image_1010.npz',
#  'image_1011.npz',
#  'image_1012.npz',
#  'image_1013.npz',
#  'image_1014.npz',
#  'image_1015.npz',
#  'image_1016.npz',
#  'image_1017.npz',
#  'image_1018.npz',
#  'image_1019.npz',
#  'image_102.npz',
#  'image_1020.npz',
#  'image_1021.npz',
#  'image_1022.npz',
#  'image_1023.npz',
#  'image_1024.npz',
#  'image_1025.npz',
#  'image_1026.npz',
#  'image_1027.npz',
#  'image_1028.npz',
#  'image_1029.npz',
#  'image_103.npz',
#  'image_1030.npz',
#  'image_1031.npz',
#  'image_1032.npz',
#  'image_1033.npz',
#  'image_1034.npz',
#  'image_1035.npz',
#  'image_1036.npz',
#  'image_1037.npz',
#  'image_1038.npz',
#  'image_1039.npz',
#  'image_104.npz',
#  'image_1040.npz',
#  'image_1041.npz',
#  'image_1042.npz',
#  'image_1043.npz',
#  'image_1044.npz',
#  'image_1045.npz',
#  'image_1046.npz',
#  'image_1047.npz',
#  'image_1048.npz',
#  'image_1049.npz',
#  'image_105.npz',
#  'image_1050.npz',
#  'image_1051.npz',
#  'image_1052.npz',
#  'image_1053.npz',
#  'image_1054.npz',
#  'image_1055.npz',
#  'image_1056.npz',
#  'image_1057.npz',
#  'image_1058.npz',
#  'image_1059.npz',
#  'image_106.npz',
#  'image_1060.npz',
#  'image_1061.npz',
#  'image_1062.npz',
#  'image_1063.npz',
#  'image_1064.npz',
#  'image_1065.npz',
#  'image_1066.npz',
#  'image_1067.npz',
#  'image_1068.npz',
#  'image_1069.npz',
#  'image_107.npz',
#  'image_1070.npz',
#  'image_1071.npz',
#  'image_1072.npz',
#  'image_1073.npz',
#  'image_1074.npz',
#  'image_1075.npz',
#  'image_1076.npz',
#  'image_1077.npz',
#  'image_1078.npz',
#  'image_1079.npz',
#  'image_108.npz',
#  'image_1080.npz',
#  'image_1081.npz',
#  'image_1082.npz',
#  'image_1083.npz',
#  'image_1084.npz',
#  'image_1085.npz',
#  'image_1086.npz',
#  'image_1087.npz',
#  'image_1088.npz',
#  'image_1089.npz',
#  'image_109.npz',
#  'image_1090.npz',
#  'image_1091.npz',
#  'image_1092.npz',
#  'image_1093.npz',
#  'image_1094.npz',
#  'image_1095.npz',
#  'image_1096.npz',
#  'image_1097.npz',
#  'image_1098.npz',
#  'image_1099.npz',
#  'image_11.npz',
#  'image_110.npz',
#  'image_1100.npz',
#  'image_1101.npz',
#  'image_1102.npz',
#  'image_1103.npz',
#  'image_1104.npz',
#  'image_1105.npz',
#  'image_1106.npz',
#  'image_1107.npz',
#  'image_1108.npz',
#  'image_1109.npz',
#  'image_111.npz',
#  'image_1110.npz',
#  'image_1111.npz',
#  'image_1112.npz',
#  'image_1113.npz',
#  'image_1114.npz',
#  'image_1115.npz',
#  'image_1116.npz',
#  'image_1117.npz',
#  'image_1118.npz',
#  'image_1119.npz',
#  'image_112.npz',
#  'image_1120.npz',
#  'image_1121.npz',
#  'image_1122.npz',
#  'image_1123.npz',
#  'image_1124.npz',
#  'image_1125.npz',
#  'image_1126.npz',
#  'image_1127.npz',
#  'image_1128.npz',
#  'image_1129.npz',
#  'image_113.npz',
#  'image_1130.npz',
#  'image_1131.npz',
#  'image_1132.npz',
#  'image_1133.npz',
#  'image_1134.npz',
#  'image_1135.npz',
#  'image_1136.npz',
#  'image_1137.npz',
#  'image_1138.npz',
#  'image_1139.npz',
#  'image_114.npz',
#  'image_1140.npz',
#  'image_1141.npz',
#  'image_1142.npz',
#  'image_1143.npz',
#  'image_1144.npz',
#  'image_1145.npz',
#  'image_1146.npz',
#  'image_1147.npz',
#  'image_1148.npz',
#  'image_1149.npz',
#  'image_115.npz',
#  'image_1150.npz',
#  'image_1151.npz',
#  'image_1152.npz',
#  'image_1153.npz',
#  'image_1154.npz',
#  'image_1155.npz',
#  'image_1156.npz',
#  'image_1157.npz',
#  'image_1158.npz',
#  'image_1159.npz',
#  'image_116.npz',
#  'image_1160.npz',
#  'image_1161.npz',
#  'image_1162.npz',
#  'image_1163.npz',
#  'image_1164.npz',
#  'image_1165.npz',
#  'image_1166.npz',
#  'image_1167.npz',
#  'image_1168.npz',
#  'image_1169.npz',
#  'image_117.npz',
#  'image_1170.npz',
#  'image_1171.npz',
#  'image_1172.npz',
#  'image_1173.npz',
#  'image_1174.npz',
#  'image_1175.npz',
#  'image_1176.npz',
#  'image_1177.npz',
#  'image_1178.npz',
#  'image_1179.npz',
#  'image_118.npz',
#  'image_1180.npz',
#  'image_1181.npz',
#  'image_1182.npz',
#  'image_1183.npz',
#  'image_1184.npz',
#  'image_1185.npz',
#  'image_1186.npz',
#  'image_1187.npz',
#  'image_1188.npz',
#  'image_1189.npz',
#  'image_119.npz',
#  'image_1190.npz',
#  'image_1191.npz',
#  'image_1192.npz',
#  'image_1193.npz',
#  'image_1194.npz',
#  'image_1195.npz',
#  'image_1196.npz',
#  'image_1197.npz',
#  'image_1198.npz',
#  'image_1199.npz',
#  'image_12.npz',
#  'image_120.npz',
#  'image_1200.npz',
#  'image_1201.npz',
#  'image_1202.npz',
#  'image_1203.npz',
#  'image_1204.npz',
#  'image_1205.npz',
#  'image_1206.npz',
#  'image_1207.npz',
#  'image_1208.npz',
#  'image_1209.npz',
#  'image_121.npz',
#  'image_1210.npz',
#  'image_1211.npz',
#  'image_1212.npz',
#  'image_1213.npz',
#  'image_1214.npz',
#  'image_1215.npz',
#  'image_1216.npz',
#  'image_1217.npz',
#  'image_1218.npz',
#  'image_1219.npz',
#  'image_122.npz',
#  'image_1220.npz',
#  'image_1221.npz',
#  'image_1222.npz',
#  'image_1223.npz',
#  'image_1224.npz',
#  'image_1225.npz',
#  'image_1226.npz',
#  'image_1227.npz',
#  'image_1228.npz',
#  'image_1229.npz',
#  'image_123.npz',
#  'image_1230.npz',
#  'image_1231.npz',
#  'image_1232.npz',
#  'image_1233.npz',
#  'image_1234.npz',
#  'image_1235.npz',
#  'image_1236.npz',
#  'image_1237.npz',
#  'image_1238.npz',
#  'image_1239.npz',
#  'image_124.npz',
#  'image_1240.npz',
#  'image_1241.npz',
#  'image_1242.npz',
#  'image_1243.npz',
#  'image_1244.npz',
#  'image_1245.npz',
#  'image_1246.npz',
#  'image_1247.npz',
#  'image_1248.npz',
#  'image_1249.npz',
#  'image_125.npz',
#  'image_1250.npz',
#  'image_1251.npz',
#  'image_1252.npz',
#  'image_1253.npz',
#  'image_1254.npz',
#  'image_1255.npz',
#  'image_1256.npz',
#  'image_1257.npz',
#  'image_1258.npz',
#  'image_1259.npz',
#  'image_126.npz',
#  'image_1260.npz',
#  'image_1261.npz',
#  'image_1262.npz',
#  'image_1263.npz',
#  'image_1264.npz',
#  'image_1265.npz',
#  'image_1266.npz',
#  'image_1267.npz',
#  'image_1268.npz',
#  'image_1269.npz',
#  'image_127.npz',
#  'image_1270.npz',
#  'image_1271.npz',
#  'image_1272.npz',
#  'image_1273.npz',
#  'image_1274.npz',
#  'image_1275.npz',
#  'image_1276.npz',
#  'image_1277.npz',
#  'image_1278.npz',
#  'image_1279.npz',
#  'image_128.npz',
#  'image_1280.npz',
#  'image_1281.npz',
#  'image_1282.npz',
#  'image_1283.npz',
#  'image_1284.npz',
#  'image_1285.npz',
#  'image_1286.npz',
#  'image_1287.npz',
#  'image_1288.npz',
#  'image_1289.npz',
#  'image_129.npz',
#  'image_1290.npz',
#  'image_1291.npz',
#  'image_1292.npz',
#  'image_1293.npz',
#  'image_1294.npz',
#  'image_1295.npz',
#  'image_1296.npz',
#  'image_1297.npz',
#  'image_1298.npz',
#  'image_1299.npz',
#  'image_13.npz',
#  'image_130.npz',
#  'image_1300.npz',
#  'image_1301.npz',
#  'image_1302.npz',
#  'image_1303.npz',
#  'image_1304.npz',
#  'image_1305.npz',
#  'image_1306.npz',
#  'image_1307.npz',
#  'image_1308.npz',
#  'image_1309.npz',
#  'image_131.npz',
#  'image_1310.npz',
#  'image_1311.npz',
#  'image_1312.npz',
#  'image_1313.npz',
#  'image_1314.npz',
#  'image_1315.npz',
#  'image_1316.npz',
#  'image_1317.npz',
#  'image_1318.npz',
#  'image_1319.npz',
#  'image_132.npz',
#  'image_1320.npz',
#  'image_1321.npz',
#  'image_1322.npz',
#  'image_1323.npz',
#  'image_1324.npz',
#  'image_1325.npz',
#  'image_1326.npz',
#  'image_1327.npz',
#  'image_1328.npz',
#  'image_1329.npz',
#  'image_133.npz',
#  'image_1330.npz',
#  'image_1331.npz',
#  'image_1332.npz',
#  'image_1333.npz',
#  'image_1334.npz',
#  'image_1335.npz',
#  'image_1336.npz',
#  'image_1337.npz',
#  'image_1338.npz',
#  'image_1339.npz',
#  'image_134.npz',
#  'image_1340.npz',
#  'image_1341.npz',
#  'image_1342.npz',
#  'image_1343.npz',
#  'image_1344.npz',
#  'image_1345.npz',
#  'image_1346.npz',
#  'image_1347.npz',
#  'image_1348.npz',
#  'image_1349.npz',
#  'image_135.npz',
#  'image_1350.npz',
#  'image_1351.npz',
#  'image_1352.npz',
#  'image_1353.npz',
#  'image_1354.npz',
#  'image_1355.npz',
#  'image_1356.npz',
#  'image_1357.npz',
#  'image_1358.npz',
#  'image_1359.npz',
#  'image_136.npz',
#  'image_1360.npz',
#  'image_1361.npz',
#  'image_1362.npz',
#  'image_1363.npz',
#  'image_1364.npz',
#  'image_1365.npz',
#  'image_1366.npz',
#  'image_1367.npz',
#  'image_1368.npz',
#  'image_1369.npz',
#  'image_137.npz',
#  'image_1370.npz',
#  'image_1371.npz',
#  'image_1372.npz',
#  'image_1373.npz',
#  'image_1374.npz',
#  'image_1375.npz',
#  'image_1376.npz',
#  'image_1377.npz',
#  'image_1378.npz',
#  'image_1379.npz',
#  'image_138.npz',
#  'image_1380.npz',
#  'image_1381.npz',
#  'image_1382.npz',
#  'image_1383.npz',
#  'image_1384.npz',
#  'image_1385.npz',
#  'image_1386.npz',
#  'image_1387.npz',
#  'image_1388.npz',
#  'image_1389.npz',
#  'image_139.npz',
#  'image_1390.npz',
#  'image_1391.npz',
#  'image_1392.npz',
#  'image_1393.npz',
#  'image_1394.npz',
#  'image_1395.npz',
#  'image_1396.npz',
#  'image_1397.npz',
#  'image_1398.npz',
#  'image_1399.npz',
#  'image_14.npz',
#  'image_140.npz',
#  'image_1400.npz',
#  'image_1401.npz',
#  'image_1402.npz',
#  'image_1403.npz',
#  'image_1404.npz',
#  'image_1405.npz',
#  'image_1406.npz',
#  'image_1407.npz',
#  'image_1408.npz',
#  'image_1409.npz',
#  'image_141.npz',
#  'image_1410.npz',
#  'image_1411.npz',
#  'image_1412.npz',
#  'image_1413.npz',
#  'image_1414.npz',
#  'image_1415.npz',
#  'image_1416.npz',
#  'image_1417.npz',
#  'image_1418.npz',
#  'image_1419.npz',
#  'image_142.npz',
#  'image_1420.npz',
#  'image_1421.npz',
#  'image_1422.npz',
#  'image_1423.npz',
#  'image_1424.npz',
#  'image_1425.npz',
#  'image_1426.npz',
#  'image_1427.npz',
#  'image_1428.npz',
#  'image_1429.npz',
#  'image_143.npz',
#  'image_1430.npz',
#  'image_1431.npz',
#  'image_1432.npz',
#  'image_1433.npz',
#  'image_1434.npz',
#  'image_1435.npz',
#  'image_1436.npz',
#  'image_1437.npz',
#  'image_1438.npz',
#  'image_1439.npz',
#  'image_144.npz',
#  'image_1440.npz',
#  'image_1441.npz',
#  'image_1442.npz',
#  'image_1443.npz',
#  'image_1444.npz',
#  'image_1445.npz',
#  'image_1446.npz',
#  'image_1447.npz',
#  'image_1448.npz',
#  'image_1449.npz',
#  'image_145.npz',
#  'image_1450.npz',
#  'image_1451.npz',
#  'image_1452.npz',
#  'image_1453.npz',
#  'image_1454.npz',
#  'image_1455.npz',
#  'image_1456.npz',
#  'image_1457.npz',
#  'image_1458.npz',
#  'image_1459.npz',
#  'image_146.npz',
#  'image_1460.npz',
#  'image_1461.npz',
#  'image_1462.npz',
#  'image_1463.npz',
#  'image_1464.npz',
#  'image_1465.npz',
#  'image_1466.npz',
#  'image_1467.npz',
#  'image_1468.npz',
#  'image_1469.npz',
#  'image_147.npz',
#  'image_1470.npz',
#  'image_1471.npz',
#  'image_1472.npz',
#  'image_1473.npz',
#  'image_1474.npz',
#  'image_1475.npz',
#  'image_1476.npz',
#  'image_1477.npz',
#  'image_1478.npz',
#  'image_1479.npz',
#  'image_148.npz',
#  'image_1480.npz',
#  'image_1481.npz',
#  'image_1482.npz',
#  'image_1483.npz',
#  'image_1484.npz',
#  'image_1485.npz',
#  'image_1486.npz',
#  'image_1487.npz',
#  'image_1488.npz',
#  'image_1489.npz',
#  'image_149.npz',
#  'image_1490.npz',
#  'image_1491.npz',
#  'image_1492.npz',
#  'image_1493.npz',
#  'image_1494.npz',
#  'image_1495.npz',
#  'image_1496.npz',
#  'image_1497.npz',
#  'image_1498.npz',
#  'image_1499.npz',
#  'image_15.npz',
#  'image_150.npz',
#  'image_1500.npz',
#  'image_1501.npz',
#  'image_1502.npz',
#  'image_1503.npz',
#  'image_1504.npz',
#  'image_1505.npz',
#  'image_1506.npz',
#  'image_1507.npz',
#  'image_1508.npz',
#  'image_1509.npz',
#  'image_151.npz',
#  'image_1510.npz',
#  'image_1511.npz',
#  'image_1512.npz',
#  'image_1513.npz',
#  'image_1514.npz',
#  'image_1515.npz',
#  'image_1516.npz',
#  'image_1517.npz',
#  'image_1518.npz',
#  'image_1519.npz',
#  'image_152.npz',
#  'image_1520.npz',
#  'image_1521.npz',
#  'image_1522.npz',
#  'image_1523.npz',
#  'image_1524.npz',
#  'image_1525.npz',
#  'image_1526.npz',
#  'image_1527.npz',
#  'image_1528.npz',
#  'image_1529.npz',
#  'image_153.npz',
#  'image_1530.npz',
#  'image_1531.npz',
#  'image_1532.npz',
#  'image_1533.npz',
#  'image_1534.npz',
#  'image_1535.npz',
#  'image_1536.npz',
#  'image_1537.npz',
#  'image_1538.npz',
#  'image_1539.npz',
#  'image_154.npz',
#  'image_1540.npz',
#  'image_1541.npz',
#  'image_1542.npz',
#  'image_1543.npz',
#  'image_1544.npz',
#  'image_1545.npz',
#  'image_1546.npz',
#  'image_1547.npz',
#  'image_1548.npz',
#  'image_1549.npz',
#  'image_155.npz',
#  'image_1550.npz',
#  'image_1551.npz',
#  'image_1552.npz',
#  'image_1553.npz',
#  'image_1554.npz',
#  'image_1555.npz',
#  'image_1556.npz',
#  'image_1557.npz',
#  'image_1558.npz',
#  'image_1559.npz',
#  'image_156.npz',
#  'image_1560.npz',
#  'image_1561.npz',
#  'image_1562.npz',
#  'image_1563.npz',
#  'image_1564.npz',
#  'image_1565.npz',
#  'image_1566.npz',
#  'image_1567.npz',
#  'image_1568.npz',
#  'image_1569.npz',
#  'image_157.npz',
#  'image_1570.npz',
#  'image_1571.npz',
#  'image_1572.npz',
#  'image_1573.npz',
#  'image_1574.npz',
#  'image_1575.npz',
#  'image_1576.npz',
#  'image_1577.npz',
#  'image_1578.npz',
#  'image_1579.npz',
#  'image_158.npz',
#  'image_1580.npz',
#  'image_1581.npz',
#  'image_1582.npz',
#  'image_1583.npz',
#  'image_1584.npz',
#  'image_1585.npz',
#  'image_1586.npz',
#  'image_1587.npz',
#  'image_1588.npz',
#  'image_1589.npz',
#  'image_159.npz',
#  'image_1590.npz',
#  'image_1591.npz',
#  'image_1592.npz',
#  'image_1593.npz',
#  'image_1594.npz',
#  'image_1595.npz',
#  'image_1596.npz',
#  'image_1597.npz',
#  'image_1598.npz',
#  'image_1599.npz',
#  'image_16.npz',
#  'image_160.npz',
#  'image_1600.npz',
#  'image_1601.npz',
#  'image_1602.npz',
#  'image_1603.npz',
#  'image_1604.npz',
#  'image_1605.npz',
#  'image_1606.npz',
#  'image_1607.npz',
#  'image_1608.npz',
#  'image_1609.npz',
#  'image_161.npz',
#  'image_1610.npz',
#  'image_1611.npz',
#  'image_1612.npz',
#  'image_1613.npz',
#  'image_1614.npz',
#  'image_1615.npz',
#  'image_1616.npz',
#  'image_1617.npz',
#  'image_1618.npz',
#  'image_1619.npz',
#  'image_162.npz',
#  'image_1620.npz',
#  'image_1621.npz',
#  'image_1622.npz',
#  'image_1623.npz',
#  'image_1624.npz',
#  'image_1625.npz',
#  'image_1626.npz',
#  'image_1627.npz',
#  'image_1628.npz',
#  'image_1629.npz',
#  'image_163.npz',
#  'image_1630.npz',
#  'image_1631.npz',
#  'image_1632.npz',
#  'image_1633.npz',
#  'image_1634.npz',
#  'image_1635.npz',
#  'image_1636.npz',
#  'image_1637.npz',
#  'image_1638.npz',
#  'image_1639.npz',
#  'image_164.npz',
#  'image_1640.npz',
#  'image_1641.npz',
#  'image_1642.npz',
#  'image_1643.npz',
#  'image_1644.npz',
#  'image_1645.npz',
#  'image_1646.npz',
#  'image_1647.npz',
#  'image_1648.npz',
#  'image_1649.npz',
#  'image_165.npz',
#  'image_1650.npz',
#  'image_1651.npz',
#  'image_1652.npz',
#  'image_1653.npz',
#  'image_1654.npz',
#  'image_1655.npz',
#  'image_1656.npz',
#  'image_1657.npz',
#  'image_1658.npz',
#  'image_1659.npz',
#  'image_166.npz',
#  'image_1660.npz',
#  'image_1661.npz',
#  'image_1662.npz',
#  'image_1663.npz',
#  'image_1664.npz',
#  'image_1665.npz',
#  'image_1666.npz',
#  'image_1667.npz',
#  'image_1668.npz',
#  'image_1669.npz',
#  'image_167.npz',
#  'image_1670.npz',
#  'image_1671.npz',
#  'image_1672.npz',
#  'image_1673.npz',
#  'image_1674.npz',
#  'image_1675.npz',
#  'image_1676.npz',
#  'image_1677.npz',
#  'image_1678.npz',
#  'image_1679.npz',
#  'image_168.npz',
#  'image_1680.npz',
#  'image_1681.npz',
#  'image_1682.npz',
#  'image_1683.npz',
#  'image_1684.npz',
#  'image_1685.npz',
#  'image_1686.npz',
#  'image_1687.npz',
#  'image_1688.npz',
#  'image_1689.npz',
#  'image_169.npz',
#  'image_1690.npz',
#  'image_1691.npz',
#  'image_1692.npz',
#  'image_1693.npz',
#  'image_1694.npz',
#  'image_1695.npz',
#  'image_1696.npz',
#  'image_1697.npz',
#  'image_1698.npz',
#  'image_1699.npz',
#  'image_17.npz',
#  'image_170.npz',
#  'image_1700.npz',
#  'image_1701.npz',
#  'image_1702.npz',
#  'image_1703.npz',
#  'image_1704.npz',
#  'image_1705.npz',
#  'image_1706.npz',
#  'image_1707.npz',
#  'image_1708.npz',
#  'image_1709.npz',
#  'image_171.npz',
#  'image_1710.npz',
#  'image_1711.npz',
#  'image_1712.npz',
#  'image_1713.npz',
#  'image_1714.npz',
#  'image_1715.npz',
#  'image_1716.npz',
#  'image_1717.npz',
#  'image_1718.npz',
#  'image_1719.npz',
#  'image_172.npz',
#  'image_1720.npz',
#  'image_1721.npz',
#  'image_1722.npz',
#  'image_1723.npz',
#  'image_1724.npz',
#  'image_1725.npz',
#  'image_1726.npz',
#  'image_1727.npz',
#  'image_1728.npz',
#  'image_1729.npz',
#  'image_173.npz',
#  'image_1730.npz',
#  'image_1731.npz',
#  'image_1732.npz',
#  'image_1733.npz',
#  'image_1734.npz',
#  'image_1735.npz',
#  'image_1736.npz',
#  'image_1737.npz',
#  'image_1738.npz',
#  'image_1739.npz',
#  'image_174.npz',
#  'image_1740.npz',
#  'image_1741.npz',
#  'image_1742.npz',
#  'image_1743.npz',
#  'image_1744.npz',
#  'image_1745.npz',
#  'image_1746.npz',
#  'image_1747.npz',
#  'image_1748.npz',
#  'image_1749.npz',
#  'image_175.npz',
#  'image_1750.npz',
#  'image_1751.npz',
#  'image_1752.npz',
#  'image_1753.npz',
#  'image_1754.npz',
#  'image_1755.npz',
#  'image_1756.npz',
#  'image_1757.npz',
#  'image_1758.npz',
#  'image_1759.npz',
#  'image_176.npz',
#  'image_1760.npz',
#  'image_1761.npz',
#  'image_1762.npz',
#  'image_1763.npz',
#  'image_1764.npz',
#  'image_1765.npz',
#  'image_1766.npz',
#  'image_1767.npz',
#  'image_1768.npz',
#  'image_1769.npz',
#  'image_177.npz',
#  'image_1770.npz',
#  'image_1771.npz',
#  'image_1772.npz',
#  'image_1773.npz',
#  'image_1774.npz',
#  'image_1775.npz',
#  'image_1776.npz',
#  'image_1777.npz',
#  'image_1778.npz',
#  'image_1779.npz',
#  'image_178.npz',
#  'image_1780.npz',
#  'image_1781.npz',
#  'image_1782.npz',
#  'image_1783.npz',
#  'image_1784.npz',
#  'image_1785.npz',
#  'image_1786.npz',
#  'image_1787.npz',
#  'image_1788.npz',
#  'image_1789.npz',
#  'image_179.npz',
#  'image_1790.npz',
#  'image_1791.npz',
#  'image_1792.npz',
#  'image_1793.npz',
#  'image_1794.npz',
#  'image_1795.npz',
#  'image_1796.npz',
#  'image_1797.npz',
#  'image_1798.npz',
#  'image_1799.npz',
#  'image_18.npz',
#  'image_180.npz',
#  'image_1800.npz',
#  'image_1801.npz',
#  'image_1802.npz',
#  'image_1803.npz',
#  'image_1804.npz',
#  'image_1805.npz',
#  'image_1806.npz',
#  'image_1807.npz',
#  'image_1808.npz',
#  'image_1809.npz',
#  'image_181.npz',
#  'image_1810.npz',
#  'image_1811.npz',
#  'image_1812.npz',
#  'image_1813.npz',
#  'image_1814.npz',
#  'image_1815.npz',
#  'image_1816.npz',
#  'image_1817.npz',
#  'image_1818.npz',
#  'image_1819.npz',
#  'image_182.npz',
#  'image_1820.npz',
#  'image_1821.npz',
#  'image_1822.npz',
#  'image_1823.npz',
#  'image_1824.npz',
#  'image_1825.npz',
#  'image_1826.npz',
#  'image_1827.npz',
#  'image_1828.npz',
#  'image_1829.npz',
#  'image_183.npz',
#  'image_1830.npz',
#  'image_1831.npz',
#  'image_1832.npz',
#  'image_1833.npz',
#  'image_1834.npz',
#  'image_1835.npz',
#  'image_1836.npz',
#  'image_1837.npz',
#  'image_1838.npz',
#  'image_1839.npz',
#  'image_184.npz',
#  'image_1840.npz',
#  'image_1841.npz',
#  'image_1842.npz',
#  'image_1843.npz',
#  'image_1844.npz',
#  'image_1845.npz',
#  'image_1846.npz',
#  'image_1847.npz',
#  'image_1848.npz',
#  'image_1849.npz',
#  'image_185.npz',
#  'image_1850.npz',
#  'image_1851.npz',
#  'image_1852.npz',
#  'image_1853.npz',
#  'image_1854.npz',
#  'image_1855.npz',
#  'image_1856.npz',
#  'image_1857.npz',
#  'image_1858.npz',
#  'image_1859.npz',
#  'image_186.npz',
#  'image_1860.npz',
#  'image_1861.npz',
#  'image_1862.npz',
#  'image_1863.npz',
#  'image_1864.npz',
#  'image_1865.npz',
#  'image_1866.npz',
#  'image_1867.npz',
#  'image_1868.npz',
#  'image_1869.npz',
#  'image_187.npz',
#  'image_1870.npz',
#  'image_1871.npz',
#  'image_1872.npz',
#  'image_1873.npz',
#  'image_1874.npz',
#  'image_1875.npz',
#  'image_1876.npz',
#  'image_1877.npz',
#  'image_1878.npz',
#  'image_1879.npz',
#  'image_188.npz',
#  'image_1880.npz',
#  'image_1881.npz',
#  'image_1882.npz',
#  'image_1883.npz',
#  'image_1884.npz',
#  'image_1885.npz',
#  'image_1886.npz',
#  'image_1887.npz',
#  'image_1888.npz',
#  'image_1889.npz',
#  'image_189.npz',
#  'image_1890.npz',
#  'image_1891.npz',
#  'image_1892.npz',
#  'image_1893.npz',
#  'image_1894.npz',
#  'image_1895.npz',
#  'image_1896.npz',
#  'image_1897.npz',
#  'image_1898.npz',
#  ...]

# %%
import h5py
hf = h5py.File('data.h5', 'w')
hf.create_dataset('image', data=d1)
hf.create_dataset('label', data=d2)
